# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, clear_output

os.environ['TF_CUDNN_USE_AUTOTUNE'] = '0'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

import tensorflow as tf
from keras import layers, models, losses, regularizers
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

print("GPU Trovate:", len(tf.config.list_physical_devices('GPU')))
for gpu in tf.config.list_physical_devices('GPU'):
    print("Nome:", gpu.name)

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("Memoria GPU configurata in modalità dinamica.")
    except RuntimeError as e:
        print("Errore GPU:", e)

tf.keras.backend.clear_session()

physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    try:
        for gpu in physical_devices:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("✅ GPU Memory Growth abilitato con successo.")
    except RuntimeError as e:
        print(f"Errore configurazione GPU: {e}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1784062315.753264   72486 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPU Trovate: 1
# Nome: /physical_device:GPU:0
# Memoria GPU configurata in modalità dinamica.
# ✅ GPU Memory Growth abilitato con successo.

# %%
def embedded_summary(model, input_shape=(1, 120, 18), is_int8=False):
    total_params = model.count_params()
    
    bytes_per_param = 1 if is_int8 else 4
    estimated_flash_kb = (total_params * bytes_per_param) / 1024
    
    bytes_per_activation = 1 if is_int8 else 4
    max_adjacent_ram_kb = 0
    
    previous_layer_size = (np.prod(input_shape) * bytes_per_activation) / 1024
    
    for layer in model.layers:
        if layer.__class__.__name__ == 'InputLayer' or not hasattr(layer, 'output_shape'):
            continue
            
        output_shape = layer.output_shape
        if isinstance(output_shape, list):
            num_elements = sum([np.prod([dim for dim in shape[1:] if dim is not None]) for shape in output_shape])
        else:
            num_elements = np.prod([dim for dim in output_shape[1:] if dim is not None])
            
        current_layer_size = (num_elements * bytes_per_activation) / 1024
        
        current_peak = previous_layer_size + current_layer_size
        
        if current_peak > max_adjacent_ram_kb:
            max_adjacent_ram_kb = current_peak
            
        previous_layer_size = current_layer_size

    print("============================================")
    mode_str = "INT8 (Quantizzato)" if is_int8 else "FLOAT32 (Training)"
    print(f"   REPORT REQUISITI ESP32-S3 [{mode_str}]   ")
    print("============================================")
    print(f" Memoria FLASH stimata : ~{estimated_flash_kb:.2f} KB  (Limite: 800 KB)")
    print(f" Memoria SRAM stimata  : ~{max_adjacent_ram_kb:.2f} KB (Limite: 300 KB)")
    print("============================================\n")

# %%
import itertools
PERM_INDICES = tf.constant(list(itertools.permutations([0, 1, 2, 3])), dtype=tf.int32)
ROOM_DIMS = tf.constant([4.8, 7.2], dtype=tf.float32)

def hungarian_total_loss(y_true, y_pred):
    y_true_coords = tf.reshape(y_true[:, :8], (-1, 4, 2))
    y_pred_coords = tf.reshape(y_pred[:, :8], (-1, 4, 2))
    y_true_mask = tf.reshape(y_true[:, 8:], (-1, 4, 1))
    y_pred_mask = tf.reshape(y_pred[:, 8:], (-1, 4, 1))

    y_pred_coords_perm = tf.gather(y_pred_coords, PERM_INDICES, axis=1) 
    y_pred_mask_perm = tf.gather(y_pred_mask, PERM_INDICES, axis=1)

    y_true_coords_exp = tf.expand_dims(y_true_coords, 1) 
    y_true_mask_exp = tf.expand_dims(y_true_mask, 1)

    sq_diff = tf.square(y_true_coords_exp - y_pred_coords_perm)
    coords_cost = tf.reduce_sum(sq_diff * y_true_mask_exp, axis=[2, 3]) 
    
    num_valid_people = tf.reduce_sum(y_true_mask_exp[:, 0, :, :], axis=[1, 2]) + 1e-6
    coords_cost_norm = coords_cost / tf.expand_dims(num_valid_people, axis=-1)

    #bce = tf.keras.backend.binary_crossentropy(y_true_mask_exp, y_pred_mask_perm)
    y_pred_mask_perm_safe = tf.clip_by_value(y_pred_mask_perm, 1e-7, 1.0 - 1e-7)
    bce = tf.keras.backend.binary_crossentropy(y_true_mask_exp, y_pred_mask_perm_safe)
    mask_cost_norm = tf.reduce_mean(bce, axis=[2, 3]) 

    total_cost = coords_cost_norm + (1.5 * mask_cost_norm) 
    return tf.reduce_min(total_cost, axis=1) 

def hungarian_rmse_metres(y_true, y_pred):
    y_true_coords = tf.reshape(y_true[:, :8], (-1, 4, 2))
    y_pred_coords = tf.reshape(y_pred[:, :8], (-1, 4, 2))
    y_true_mask = tf.reshape(y_true[:, 8:], (-1, 4, 1))

    y_pred_coords_perm = tf.gather(y_pred_coords, PERM_INDICES, axis=1)
    y_true_coords_exp = tf.expand_dims(y_true_coords, 1)
    y_true_mask_exp = tf.expand_dims(y_true_mask, 1)

    sq_diff = tf.square(y_true_coords_exp - y_pred_coords_perm)
    coords_cost = tf.reduce_sum(sq_diff * y_true_mask_exp, axis=[2, 3])
    
    min_coords_cost = tf.reduce_min(coords_cost, axis=1)
    
    num_valid_people = tf.reduce_sum(y_true_mask_exp[:, 0, :, :], axis=[1, 2]) + 1e-6
    
    return tf.sqrt(min_coords_cost / num_valid_people)

def hungarian_mask_acc(y_true, y_pred):
    y_true_mask = tf.reshape(y_true[:, 8:], (-1, 4, 1)) 
    y_pred_mask = tf.reshape(y_pred[:, 8:], (-1, 4, 1)) 
    y_pred_mask_perm = tf.gather(y_pred_mask, PERM_INDICES, axis=1)
    
    y_true_coords = tf.reshape(y_true[:, :8], (-1, 4, 2))
    y_pred_coords = tf.reshape(y_pred[:, :8], (-1, 4, 2))
    y_pred_coords_perm = tf.gather(y_pred_coords, PERM_INDICES, axis=1)
    y_true_coords_exp = tf.expand_dims(y_true_coords, 1)
    y_true_mask_exp = tf.expand_dims(y_true_mask, 1)

    sq_diff = tf.square(y_true_coords_exp - y_pred_coords_perm)
    coords_cost = tf.reduce_sum(sq_diff * y_true_mask_exp, axis=[2, 3])
    num_valid_people = tf.reduce_sum(y_true_mask_exp[:, 0, :, :], axis=[1, 2]) + 1e-6
    coords_cost_norm = coords_cost / tf.expand_dims(num_valid_people, axis=-1)
    
    y_pred_mask_perm_safe = tf.clip_by_value(y_pred_mask_perm, 1e-7, 1.0 - 1e-7)
    bce = tf.keras.backend.binary_crossentropy(y_true_mask_exp, y_pred_mask_perm_safe)
    mask_cost_norm = tf.reduce_mean(bce, axis=[2, 3])
    
    total_cost = coords_cost_norm + (1.5 * mask_cost_norm)
    best_perm_idx = tf.argmin(total_cost, axis=1, output_type=tf.int32)
    
    batch_size = tf.shape(y_pred)[0]
    gather_nd_indices = tf.stack([tf.range(batch_size, dtype=tf.int32), best_perm_idx], axis=1)
    best_mask_pred = tf.gather_nd(y_pred_mask_perm, gather_nd_indices)
    
    return tf.reduce_mean(tf.keras.metrics.binary_accuracy(y_true_mask, best_mask_pred))
# Out:
# I0000 00:00:1784062318.466253   72486 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2547 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
def load_and_process_all_files(file_list, alpha=0.02):
    X_all, Y_all = [], []
    print(f"Inizio caricamento ed EMA Decluttering di {len(file_list)} file...")
    
    for i, file_path in enumerate(file_list):
        data = np.load(file_path)
        raw_iq = data['radar_cir_iq']   
        people_xy = data['people_xy'].astype(np.float32) # Assicuriamoci sia float
        people_mask = data['people_mask'] 
        T = raw_iq.shape[0]             
        
        mag = np.sqrt(raw_iq[..., 0]**2 + raw_iq[..., 1]**2)
        mag_reshaped = mag.reshape(T, 1, 120, 18) 
        
        bg = np.copy(mag_reshaped[0])
        decluttered = np.zeros_like(mag_reshaped)
        
        for t in range(T):
            bg = alpha * mag_reshaped[t] + (1 - alpha) * bg
            decluttered[t] = np.abs(mag_reshaped[t] - bg)
        
        flat_coords = people_xy.reshape(T, 8)
        combined_target = np.concatenate([flat_coords, people_mask], axis=1)

        X_all.append(decluttered)
        Y_all.append(combined_target)
        
        print(f"File {i+1}/{len(file_list)} processato.")

    X = np.concatenate(X_all, axis=0).astype(np.float32)
    Y = np.concatenate(Y_all, axis=0).astype(np.float32)
    return X, Y


# ==============================================================================
# 2. SPLIT DIVERSI SEGUENDO DIVERSI CRITERI
# ==============================================================================
# Split1 (78% train e 22% val), > windows con 3/4 persone in train
#val_indices = [23, 20, 3, 15, 7, 11] 
#train_indices = [22, 16, 17, 18, 19, 21, 0, 1, 2, 4, 12, 13, 14, 5, 6, 8, 9, 10]
# Split2 (80% train e 22% val), stesso cocetto di split 1 "STRESS TEST sul MULTIPATH"
#val_indices = [23, 20, 0, 13, 9] 
#train_indices = [22, 16, 17, 18, 19, 21, 1, 2, 3, 4, 12, 14, 15, 5, 6, 7, 8, 10, 11]
# Split3 
#val_indices = [21, 20, 3, 15, 7, 11] 
#train_indices = [22, 16, 17, 18, 19, 23, 0, 1, 2, 4, 12, 13, 14, 5, 6, 8, 9, 10]
#split4
#val_indices = [21, 20, 0, 13, 9] 
#train_indices = [22, 16, 17, 18, 19, 23, 1, 2, 3, 4, 12, 14, 15, 5, 6, 7, 8, 10, 11]
#split5
val_indices = [23, 20, 0, 15, 7, 11] 
train_indices = [22, 16, 17, 18, 19, 21, 3, 1, 2, 4, 12, 13, 14, 5, 6, 8, 9, 10]
#split 6
#val_indices = [23, 20, 3, 13, 9] 
#train_indices = [22, 16, 17, 18, 19, 21, 1, 2, 0, 4, 12, 14, 15, 5, 6, 7, 8, 10, 11]
#split 7
#val_indices = [23, 20, 3, 15, 7, 9] 
#train_indices = [22, 16, 17, 18, 19, 21, 0, 1, 2, 4, 12, 13, 14, 5, 6, 8, 11, 10]
#split 8
#val_indices = [23, 20, 0, 13, 11] 
#train_indices = [22, 16, 17, 18, 19, 21, 1, 2, 3, 4, 12, 14, 15, 5, 6, 7, 8, 10, 9]
#split 9 
#val_indices = [23, 20, 3, 13, 7, 11] 
#train_indices = [22, 16, 17, 18, 19, 21, 0, 1, 2, 4, 12, 15, 14, 5, 6, 8, 9, 10]


tutti_i_file = glob.glob("dataset/data/*.npz")
#tutti_i_file = glob.glob("dataset/*.npz")
train_files = [f for f in tutti_i_file if int(os.path.basename(f).replace("window_", "").replace(".npz", "")) in train_indices]
val_files = [f for f in tutti_i_file if int(os.path.basename(f).replace("window_", "").replace(".npz", "")) in val_indices]


print("\n--- PREPARAZIONE TRAINING SET ---")
X_train_raw, Y_train = load_and_process_all_files(train_files)

print("\n--- PREPARAZIONE VALIDATION SET ---")
X_val_raw, Y_val = load_and_process_all_files(val_files)


GLOBAL_MAX = np.percentile(X_train_raw, 99.5)
print(f"\n---> GLOBAL_MAX CALCOLATO: {GLOBAL_MAX:.2f} <---")
print("INSERISCI QUESTO VALORE NEL TUO CODE.PY PER L'INFERENZA!")

X_train = np.clip(X_train_raw, 0, GLOBAL_MAX) / GLOBAL_MAX
X_val = np.clip(X_val_raw, 0, GLOBAL_MAX) / GLOBAL_MAX

print("\n==================================================")
print(f"DATI TOTALI PRONTI E NORMALIZZATI IN RAM!")
print(f"Totale FRAME individuali di Train:      {X_train.shape[0]}")
print(f"Totale FRAME individuali di Validation: {X_val.shape[0]}")
print("==================================================")
# Out:
# --- PREPARAZIONE TRAINING SET ---
# Inizio caricamento ed EMA Decluttering di 18 file...
# File 1/18 processato.
# File 2/18 processato.
# File 3/18 processato.
# File 4/18 processato.
# File 5/18 processato.
# File 6/18 processato.
# File 7/18 processato.
# File 8/18 processato.
# File 9/18 processato.
# File 10/18 processato.
# File 11/18 processato.
# File 12/18 processato.
# File 13/18 processato.
# File 14/18 processato.
# File 15/18 processato.
# File 16/18 processato.
# File 17/18 processato.
# File 18/18 processato.
#
# --- PREPARAZIONE VALIDATION SET ---
# Inizio caricamento ed EMA Decluttering di 6 file...
# File 1/6 processato.
# File 2/6 processato.
# File 3/6 processato.
# File 4/6 processato.
# File 5/6 processato.
# File 6/6 processato.
#
# ---> GLOBAL_MAX CALCOLATO: 203.10 <---
# INSERISCI QUESTO VALORE NEL TUO CODE.PY PER L'INFERENZA!
#
# ==================================================
# DATI TOTALI PRONTI E NORMALIZZATI IN RAM!
# Totale FRAME individuali di Train:      135000
# Totale FRAME individuali di Validation: 45000
# ==================================================

# %%
def squeeze_excite_block_2d(x, filters, r=8):
    """Meccanismo di Attenzione spaziale basato su Squeeze-and-Excitation"""
    se = layers.GlobalAveragePooling2D()(x)
    se = layers.Dense(max(1, filters // r), activation='relu', use_bias=False)(se)
    se = layers.Dense(filters, activation='sigmoid', use_bias=False)(se)
    se = layers.Reshape((1, 1, filters))(se)
    return layers.Multiply()([x, se])

def residual_reduction_module_2d_mobile(x, filters, r=8, name_prefix=""):
    res = layers.DepthwiseConv2D(kernel_size=(1, 3), padding='same', use_bias=False, name=f"{name_prefix}_res_dw")(x)
    res = layers.BatchNormalization(name=f"{name_prefix}_res_bn1")(res)
    res = layers.ReLU(name=f"{name_prefix}_res_relu1")(res)
    res = layers.Conv2D(filters, kernel_size=(1, 1), padding='same', activation='relu', name=f"{name_prefix}_res_pw")(res)
    
    res = squeeze_excite_block_2d(res, filters, r=r)
    res = layers.Add(name=f"{name_prefix}_res_add")([res, x])

    
    red1 = layers.DepthwiseConv2D(kernel_size=(1, 3), strides=(1, 2), padding='same', use_bias=False, name=f"{name_prefix}_red_dw")(res)
    red1 = layers.BatchNormalization(name=f"{name_prefix}_red_bn2")(red1)
    red1 = layers.ReLU(name=f"{name_prefix}_red_relu2")(red1)
    red1 = layers.Conv2D(filters, kernel_size=(1, 1), padding='same', activation='relu', name=f"{name_prefix}_red_pw")(red1)
    
    red2 = layers.Conv2D(filters, kernel_size=(1, 1), strides=(1, 2), padding='same', activation='relu', name=f"{name_prefix}_red_conv2")(res)
    
    out = layers.Add(name=f"{name_prefix}_red_add")([red1, red2])
    return out

def build_eeai_model_v2_rrm(n_radars=6, n_antennas=3, n_bins=120):
    input_channels = n_radars * n_antennas
    inputs = layers.Input(shape=(1, n_bins, input_channels), name="radar_input")
    
    F = 64 
    r = 8  
    
    x = layers.GaussianNoise(0.01, name="input_noise")(inputs)

    x = layers.Conv2D(F, kernel_size=(1, 5), padding='same', activation='relu', name="init_conv")(x)
    
    x = residual_reduction_module_2d_mobile(x, filters=F, r=r, name_prefix="rrm1") # Bins: 120 -> 60
    x = residual_reduction_module_2d_mobile(x, filters=F, r=r, name_prefix="rrm2") # Bins: 60 -> 30
    x = residual_reduction_module_2d_mobile(x, filters=F, r=r, name_prefix="rrm3") # Bins: 30 -> 15
    x = residual_reduction_module_2d_mobile(x, filters=F, r=r, name_prefix="rrm4") # Bins: 15 -> 8
    
    # 3. Testa della rete (Flatten + Dense)
    x = layers.Flatten(name="flatten_features")(x)
    x = layers.Dropout(0.35, name="dropout_features")(x)
    
    common_feat = layers.Dense(128, activation='relu', name="dense_shared")(x)
    
    # 4. Multi-Head Output (Coordinate + Maschera presenze)
    coords_output = layers.Dense(8, activation='linear', name="coords_head")(common_feat)
    mask_output = layers.Dense(4, activation='sigmoid', name="mask_head")(common_feat)
    
    combined_output = layers.Concatenate(axis=1, name="combined_output")([coords_output, mask_output])
    
    return models.Model(inputs=inputs, outputs=combined_output, name="EEAI_Net_V2_RRM")

# %%
print("\n--- PREPARAZIONE TF.DATA PIPELINE ---")
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train))
train_dataset = train_dataset.shuffle(buffer_size=5000).batch(32).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, Y_val))
val_dataset = val_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

model_rrm = build_eeai_model_v2_rrm()

model_rrm.compile(
    optimizer='adam',
    loss=hungarian_total_loss, 
    metrics=[hungarian_rmse_metres, hungarian_mask_acc]
)

checkpoint_rrm = ModelCheckpoint("split9.keras", monitor="val_loss", save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6, verbose=1)

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)

EPOCHS = 150
embedded_summary(model_rrm, input_shape=(1, 120, 18), is_int8=False)

print("\n--- INIZIO ADDESTRAMENTO MODELLO RRM ---")
history_rrm = model_rrm.fit(
    train_dataset,
    validation_data= val_dataset,
    # batch_size=32,
    # shuffle=True,
    epochs=EPOCHS,
    callbacks=[checkpoint_rrm, reduce_lr, early_stop], 
    verbose=1
)
print("--- ADDESTRAMENTO COMPLETATO ---")
# Out:
# --- PREPARAZIONE TF.DATA PIPELINE ---
# W0000 00:00:1784062335.930361   72486 cpu_allocator_impl.cc:82] Allocation of 1166400000 exceeds 10% of free system memory.
# W0000 00:00:1784062337.165626   72486 cpu_allocator_impl.cc:82] Allocation of 1166400000 exceeds 10% of free system memory.
# ============================================
#    REPORT REQUISITI ESP32-S3 [FLOAT32 (Training)]
# ============================================
#  Memoria FLASH stimata : ~510.30 KB  (Limite: 800 KB)
#  Memoria SRAM stimata  : ~0.00 KB (Limite: 300 KB)
# ============================================
#
#
# --- INIZIO ADDESTRAMENTO MODELLO RRM ---
# Epoch 1/150
# W0000 00:00:1784062339.276418   72486 cpu_allocator_impl.cc:82] Allocation of 1166400000 exceeds 10% of free system memory.
# I0000 00:00:1784062344.521650   72560 service.cc:153] XLA service 0x7fbe340538b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1784062344.521670   72560 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce GTX 1650, Compute Capability 7.5 (Driver: 13.0.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.10.1)
# I0000 00:00:1784062344.696353   72560 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1784062345.768704   72560 cuda_dnn.cc:461] Loaded cuDNN version 91001
# I0000 00:00:1784062345.918341   72560 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_13060__.103
# I0000 00:00:1784062359.934702   72560 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4210/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9686 - hungarian_rmse_metres: 0.6841 - loss: 0.8078
# I0000 00:00:1784062387.811981   72561 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_13060__.103
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - hungarian_mask_acc: 0.9687 - hungarian_rmse_metres: 0.6838 - loss: 0.8072
# I0000 00:00:1784062403.464135   72560 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_35347__.20
# I0000 00:00:1784062408.369364   72563 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_35347__.20
# Epoch 1: val_loss improved from None to 1.16775, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 75s 12ms/step - hungarian_mask_acc: 0.9788 - hungarian_rmse_metres: 0.5327 - loss: 0.5251 - val_hungarian_mask_acc: 0.8696 - val_hungarian_rmse_metres: 0.5754 - val_loss: 1.1678 - learning_rate: 0.0010
# Epoch 2/150
# 4216/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9920 - hungarian_rmse_metres: 0.4770 - loss: 0.3581
# Epoch 2: val_loss improved from 1.16775 to 0.88483, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 28s 7ms/step - hungarian_mask_acc: 0.9895 - hungarian_rmse_metres: 0.4281 - loss: 0.3322 - val_hungarian_mask_acc: 0.9001 - val_hungarian_rmse_metres: 0.5332 - val_loss: 0.8848 - learning_rate: 0.0010
# Epoch 3/150
# 4216/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9931 - hungarian_rmse_metres: 0.4303 - loss: 0.2987
# Epoch 3: val_loss did not improve from 0.88483
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 29s 7ms/step - hungarian_mask_acc: 0.9903 - hungarian_rmse_metres: 0.3927 - loss: 0.2885 - val_hungarian_mask_acc: 0.8828 - val_hungarian_rmse_metres: 0.5184 - val_loss: 0.9831 - learning_rate: 0.0010
# Epoch 4/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9941 - hungarian_rmse_metres: 0.4011 - loss: 0.2639
# Epoch 4: val_loss improved from 0.88483 to 0.75044, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 29s 7ms/step - hungarian_mask_acc: 0.9917 - hungarian_rmse_metres: 0.3681 - loss: 0.2553 - val_hungarian_mask_acc: 0.9246 - val_hungarian_rmse_metres: 0.5095 - val_loss: 0.7504 - learning_rate: 0.0010
# Epoch 5/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9947 - hungarian_rmse_metres: 0.3824 - loss: 0.2408
# Epoch 5: val_loss improved from 0.75044 to 0.70088, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 29s 7ms/step - hungarian_mask_acc: 0.9924 - hungarian_rmse_metres: 0.3527 - loss: 0.2353 - val_hungarian_mask_acc: 0.9254 - val_hungarian_rmse_metres: 0.4932 - val_loss: 0.7009 - learning_rate: 0.0010
# Epoch 6/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9950 - hungarian_rmse_metres: 0.3739 - loss: 0.2297
# Epoch 6: val_loss did not improve from 0.70088
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 29s 7ms/step - hungarian_mask_acc: 0.9931 - hungarian_rmse_metres: 0.3450 - loss: 0.2242 - val_hungarian_mask_acc: 0.9088 - val_hungarian_rmse_metres: 0.5027 - val_loss: 0.8272 - learning_rate: 0.0010
# Epoch 7/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9955 - hungarian_rmse_metres: 0.3653 - loss: 0.2188
# Epoch 7: val_loss did not improve from 0.70088
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 29s 7ms/step - hungarian_mask_acc: 0.9938 - hungarian_rmse_metres: 0.3369 - loss: 0.2121 - val_hungarian_mask_acc: 0.9224 - val_hungarian_rmse_metres: 0.4914 - val_loss: 0.7624 - learning_rate: 0.0010
# Epoch 8/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9958 - hungarian_rmse_metres: 0.3572 - loss: 0.2087
# Epoch 8: val_loss did not improve from 0.70088
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 29s 7ms/step - hungarian_mask_acc: 0.9944 - hungarian_rmse_metres: 0.3297 - loss: 0.2020 - val_hungarian_mask_acc: 0.9349 - val_hungarian_rmse_metres: 0.4966 - val_loss: 0.7172 - learning_rate: 0.0010
# Epoch 9/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9962 - hungarian_rmse_metres: 0.3504 - loss: 0.2000
# Epoch 9: val_loss did not improve from 0.70088
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 28s 7ms/step - hungarian_mask_acc: 0.9947 - hungarian_rmse_metres: 0.3250 - loss: 0.1960 - val_hungarian_mask_acc: 0.9352 - val_hungarian_rmse_metres: 0.5038 - val_loss: 0.7096 - learning_rate: 0.0010
# Epoch 10/150
# 4218/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9962 - hungarian_rmse_metres: 0.3469 - loss: 0.1959
# Epoch 10: val_loss did not improve from 0.70088
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 27s 7ms/step - hungarian_mask_acc: 0.9949 - hungarian_rmse_metres: 0.3205 - loss: 0.1898 - val_hungarian_mask_acc: 0.9366 - val_hungarian_rmse_metres: 0.4923 - val_loss: 0.7084 - learning_rate: 0.0010
# Epoch 11/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9948 - hungarian_rmse_metres: 0.3667 - loss: 0.2229
# Epoch 11: val_loss improved from 0.70088 to 0.67481, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 28s 7ms/step - hungarian_mask_acc: 0.9940 - hungarian_rmse_metres: 0.3254 - loss: 0.1999 - val_hungarian_mask_acc: 0.9425 - val_hungarian_rmse_metres: 0.4795 - val_loss: 0.6748 - learning_rate: 2.0000e-04
# Epoch 12/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9957 - hungarian_rmse_metres: 0.3449 - loss: 0.1967
# Epoch 12: val_loss improved from 0.67481 to 0.66280, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 29s 7ms/step - hungarian_mask_acc: 0.9949 - hungarian_rmse_metres: 0.3119 - loss: 0.1822 - val_hungarian_mask_acc: 0.9423 - val_hungarian_rmse_metres: 0.4736 - val_loss: 0.6628 - learning_rate: 2.0000e-04
# Epoch 13/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9961 - hungarian_rmse_metres: 0.3373 - loss: 0.1868
# Epoch 13: val_loss did not improve from 0.66280
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - hungarian_mask_acc: 0.9952 - hungarian_rmse_metres: 0.3062 - loss: 0.1746 - val_hungarian_mask_acc: 0.9401 - val_hungarian_rmse_metres: 0.4736 - val_loss: 0.6863 - learning_rate: 2.0000e-04
# Epoch 14/150
# 4216/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9966 - hungarian_rmse_metres: 0.3318 - loss: 0.1797
# Epoch 14: val_loss did not improve from 0.66280
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - hungarian_mask_acc: 0.9957 - hungarian_rmse_metres: 0.3022 - loss: 0.1687 - val_hungarian_mask_acc: 0.9419 - val_hungarian_rmse_metres: 0.4754 - val_loss: 0.6867 - learning_rate: 2.0000e-04
# Epoch 15/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9967 - hungarian_rmse_metres: 0.3283 - loss: 0.1765
# Epoch 15: val_loss did not improve from 0.66280
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - hungarian_mask_acc: 0.9958 - hungarian_rmse_metres: 0.2995 - loss: 0.1660 - val_hungarian_mask_acc: 0.9420 - val_hungarian_rmse_metres: 0.4737 - val_loss: 0.6826 - learning_rate: 2.0000e-04
# Epoch 16/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9967 - hungarian_rmse_metres: 0.3255 - loss: 0.1730
# Epoch 16: val_loss did not improve from 0.66280
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - hungarian_mask_acc: 0.9957 - hungarian_rmse_metres: 0.2975 - loss: 0.1636 - val_hungarian_mask_acc: 0.9414 - val_hungarian_rmse_metres: 0.4700 - val_loss: 0.6772 - learning_rate: 2.0000e-04
# Epoch 17/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9971 - hungarian_rmse_metres: 0.3227 - loss: 0.1697
# Epoch 17: val_loss did not improve from 0.66280
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9961 - hungarian_rmse_metres: 0.2954 - loss: 0.1605 - val_hungarian_mask_acc: 0.9441 - val_hungarian_rmse_metres: 0.4747 - val_loss: 0.6697 - learning_rate: 2.0000e-04
# Epoch 18/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9932 - hungarian_rmse_metres: 0.3483 - loss: 0.2095
# Epoch 18: val_loss improved from 0.66280 to 0.64849, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9929 - hungarian_rmse_metres: 0.3106 - loss: 0.1881 - val_hungarian_mask_acc: 0.9440 - val_hungarian_rmse_metres: 0.4647 - val_loss: 0.6485 - learning_rate: 4.0000e-05
# Epoch 19/150
# 4212/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9937 - hungarian_rmse_metres: 0.3404 - loss: 0.1995
# Epoch 19: val_loss improved from 0.64849 to 0.63834, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9933 - hungarian_rmse_metres: 0.3071 - loss: 0.1824 - val_hungarian_mask_acc: 0.9449 - val_hungarian_rmse_metres: 0.4635 - val_loss: 0.6383 - learning_rate: 4.0000e-05
# Epoch 20/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9942 - hungarian_rmse_metres: 0.3381 - loss: 0.1951
# Epoch 20: val_loss improved from 0.63834 to 0.63328, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9935 - hungarian_rmse_metres: 0.3058 - loss: 0.1800 - val_hungarian_mask_acc: 0.9452 - val_hungarian_rmse_metres: 0.4640 - val_loss: 0.6333 - learning_rate: 4.0000e-05
# Epoch 21/150
# 4216/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9943 - hungarian_rmse_metres: 0.3372 - loss: 0.1934
# Epoch 21: val_loss improved from 0.63328 to 0.62272, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9937 - hungarian_rmse_metres: 0.3055 - loss: 0.1787 - val_hungarian_mask_acc: 0.9461 - val_hungarian_rmse_metres: 0.4616 - val_loss: 0.6227 - learning_rate: 4.0000e-05
# Epoch 22/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9944 - hungarian_rmse_metres: 0.3351 - loss: 0.1910
# Epoch 22: val_loss did not improve from 0.62272
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9937 - hungarian_rmse_metres: 0.3040 - loss: 0.1770 - val_hungarian_mask_acc: 0.9460 - val_hungarian_rmse_metres: 0.4617 - val_loss: 0.6264 - learning_rate: 4.0000e-05
# Epoch 23/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9948 - hungarian_rmse_metres: 0.3347 - loss: 0.1895
# Epoch 23: val_loss did not improve from 0.62272
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9941 - hungarian_rmse_metres: 0.3031 - loss: 0.1757 - val_hungarian_mask_acc: 0.9456 - val_hungarian_rmse_metres: 0.4605 - val_loss: 0.6278 - learning_rate: 4.0000e-05
# Epoch 24/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9949 - hungarian_rmse_metres: 0.3333 - loss: 0.1865
# Epoch 24: val_loss did not improve from 0.62272
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9943 - hungarian_rmse_metres: 0.3026 - loss: 0.1734 - val_hungarian_mask_acc: 0.9455 - val_hungarian_rmse_metres: 0.4613 - val_loss: 0.6275 - learning_rate: 4.0000e-05
# Epoch 25/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9952 - hungarian_rmse_metres: 0.3324 - loss: 0.1850
# Epoch 25: val_loss did not improve from 0.62272
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9944 - hungarian_rmse_metres: 0.3019 - loss: 0.1725 - val_hungarian_mask_acc: 0.9449 - val_hungarian_rmse_metres: 0.4606 - val_loss: 0.6348 - learning_rate: 4.0000e-05
# Epoch 26/150
# 4216/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9951 - hungarian_rmse_metres: 0.3314 - loss: 0.1834
# Epoch 26: val_loss improved from 0.62272 to 0.61719, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9944 - hungarian_rmse_metres: 0.3011 - loss: 0.1712 - val_hungarian_mask_acc: 0.9469 - val_hungarian_rmse_metres: 0.4611 - val_loss: 0.6172 - learning_rate: 4.0000e-05
# Epoch 27/150
# 4216/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9952 - hungarian_rmse_metres: 0.3314 - loss: 0.1833
# Epoch 27: val_loss did not improve from 0.61719
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9945 - hungarian_rmse_metres: 0.3012 - loss: 0.1711 - val_hungarian_mask_acc: 0.9470 - val_hungarian_rmse_metres: 0.4602 - val_loss: 0.6209 - learning_rate: 4.0000e-05
# Epoch 28/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9954 - hungarian_rmse_metres: 0.3300 - loss: 0.1813
# Epoch 28: val_loss did not improve from 0.61719
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9946 - hungarian_rmse_metres: 0.3005 - loss: 0.1699 - val_hungarian_mask_acc: 0.9462 - val_hungarian_rmse_metres: 0.4607 - val_loss: 0.6234 - learning_rate: 4.0000e-05
# Epoch 29/150
# 4212/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9957 - hungarian_rmse_metres: 0.3290 - loss: 0.1798
# Epoch 29: val_loss did not improve from 0.61719
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9948 - hungarian_rmse_metres: 0.2996 - loss: 0.1683 - val_hungarian_mask_acc: 0.9464 - val_hungarian_rmse_metres: 0.4614 - val_loss: 0.6263 - learning_rate: 4.0000e-05
# Epoch 30/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9956 - hungarian_rmse_metres: 0.3291 - loss: 0.1798
# Epoch 30: val_loss did not improve from 0.61719
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9948 - hungarian_rmse_metres: 0.2995 - loss: 0.1681 - val_hungarian_mask_acc: 0.9463 - val_hungarian_rmse_metres: 0.4601 - val_loss: 0.6257 - learning_rate: 4.0000e-05
# Epoch 31/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9955 - hungarian_rmse_metres: 0.3285 - loss: 0.1793
# Epoch 31: val_loss did not improve from 0.61719
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9946 - hungarian_rmse_metres: 0.2991 - loss: 0.1678 - val_hungarian_mask_acc: 0.9465 - val_hungarian_rmse_metres: 0.4607 - val_loss: 0.6225 - learning_rate: 4.0000e-05
# Epoch 32/150
# 4218/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9844 - hungarian_rmse_metres: 0.3559 - loss: 0.2526
# Epoch 32: val_loss improved from 0.61719 to 0.61037, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9835 - hungarian_rmse_metres: 0.3195 - loss: 0.2331 - val_hungarian_mask_acc: 0.9452 - val_hungarian_rmse_metres: 0.4476 - val_loss: 0.6104 - learning_rate: 8.0000e-06
# Epoch 33/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9847 - hungarian_rmse_metres: 0.3491 - loss: 0.2407
# Epoch 33: val_loss improved from 0.61037 to 0.60939, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9841 - hungarian_rmse_metres: 0.3159 - loss: 0.2246 - val_hungarian_mask_acc: 0.9449 - val_hungarian_rmse_metres: 0.4462 - val_loss: 0.6094 - learning_rate: 8.0000e-06
# Epoch 34/150
# 4212/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9856 - hungarian_rmse_metres: 0.3469 - loss: 0.2342
# Epoch 34: val_loss improved from 0.60939 to 0.60269, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9848 - hungarian_rmse_metres: 0.3146 - loss: 0.2198 - val_hungarian_mask_acc: 0.9457 - val_hungarian_rmse_metres: 0.4462 - val_loss: 0.6027 - learning_rate: 8.0000e-06
# Epoch 35/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9860 - hungarian_rmse_metres: 0.3451 - loss: 0.2307
# Epoch 35: val_loss did not improve from 0.60269
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9850 - hungarian_rmse_metres: 0.3143 - loss: 0.2182 - val_hungarian_mask_acc: 0.9453 - val_hungarian_rmse_metres: 0.4462 - val_loss: 0.6057 - learning_rate: 8.0000e-06
# Epoch 36/150
# 4213/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9861 - hungarian_rmse_metres: 0.3451 - loss: 0.2301
# Epoch 36: val_loss did not improve from 0.60269
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9853 - hungarian_rmse_metres: 0.3137 - loss: 0.2165 - val_hungarian_mask_acc: 0.9452 - val_hungarian_rmse_metres: 0.4465 - val_loss: 0.6061 - learning_rate: 8.0000e-06
# Epoch 37/150
# 4216/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9865 - hungarian_rmse_metres: 0.3447 - loss: 0.2280
# Epoch 37: val_loss did not improve from 0.60269
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9854 - hungarian_rmse_metres: 0.3136 - loss: 0.2150 - val_hungarian_mask_acc: 0.9456 - val_hungarian_rmse_metres: 0.4465 - val_loss: 0.6030 - learning_rate: 8.0000e-06
# Epoch 38/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9870 - hungarian_rmse_metres: 0.3443 - loss: 0.2262
# Epoch 38: val_loss did not improve from 0.60269
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9858 - hungarian_rmse_metres: 0.3133 - loss: 0.2138 - val_hungarian_mask_acc: 0.9453 - val_hungarian_rmse_metres: 0.4469 - val_loss: 0.6051 - learning_rate: 8.0000e-06
# Epoch 39/150
# 4212/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9869 - hungarian_rmse_metres: 0.3437 - loss: 0.2255
# Epoch 39: val_loss did not improve from 0.60269
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9861 - hungarian_rmse_metres: 0.3131 - loss: 0.2120 - val_hungarian_mask_acc: 0.9456 - val_hungarian_rmse_metres: 0.4472 - val_loss: 0.6036 - learning_rate: 8.0000e-06
# Epoch 40/150
# 4218/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9768 - hungarian_rmse_metres: 0.3616 - loss: 0.2839
# Epoch 40: val_loss improved from 0.60269 to 0.57743, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9776 - hungarian_rmse_metres: 0.3242 - loss: 0.2576 - val_hungarian_mask_acc: 0.9482 - val_hungarian_rmse_metres: 0.4385 - val_loss: 0.5774 - learning_rate: 1.6000e-06
# Epoch 41/150
# 4218/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9808 - hungarian_rmse_metres: 0.3553 - loss: 0.2606
# Epoch 41: val_loss improved from 0.57743 to 0.57573, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9800 - hungarian_rmse_metres: 0.3215 - loss: 0.2431 - val_hungarian_mask_acc: 0.9483 - val_hungarian_rmse_metres: 0.4363 - val_loss: 0.5757 - learning_rate: 1.6000e-06
# Epoch 42/150
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9815 - hungarian_rmse_metres: 0.3546 - loss: 0.2548
# Epoch 42: val_loss did not improve from 0.57573
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9805 - hungarian_rmse_metres: 0.3212 - loss: 0.2396 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4354 - val_loss: 0.5758 - learning_rate: 1.6000e-06
# Epoch 43/150
# 4216/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9819 - hungarian_rmse_metres: 0.3529 - loss: 0.2510
# Epoch 43: val_loss improved from 0.57573 to 0.57560, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9807 - hungarian_rmse_metres: 0.3204 - loss: 0.2375 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4346 - val_loss: 0.5756 - learning_rate: 1.6000e-06
# Epoch 44/150
# 4213/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9824 - hungarian_rmse_metres: 0.3525 - loss: 0.2488
# Epoch 44: val_loss improved from 0.57560 to 0.57516, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9811 - hungarian_rmse_metres: 0.3197 - loss: 0.2353 - val_hungarian_mask_acc: 0.9483 - val_hungarian_rmse_metres: 0.4345 - val_loss: 0.5752 - learning_rate: 1.6000e-06
# Epoch 45/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9831 - hungarian_rmse_metres: 0.3521 - loss: 0.2467
# Epoch 45: val_loss improved from 0.57516 to 0.57399, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9816 - hungarian_rmse_metres: 0.3201 - loss: 0.2343 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4342 - val_loss: 0.5740 - learning_rate: 1.6000e-06
# Epoch 46/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9828 - hungarian_rmse_metres: 0.3520 - loss: 0.2471
# Epoch 46: val_loss did not improve from 0.57399
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9814 - hungarian_rmse_metres: 0.3201 - loss: 0.2345 - val_hungarian_mask_acc: 0.9483 - val_hungarian_rmse_metres: 0.4341 - val_loss: 0.5741 - learning_rate: 1.6000e-06
# Epoch 47/150
# 4216/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9832 - hungarian_rmse_metres: 0.3514 - loss: 0.2449
# Epoch 47: val_loss improved from 0.57399 to 0.57377, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9815 - hungarian_rmse_metres: 0.3196 - loss: 0.2330 - val_hungarian_mask_acc: 0.9483 - val_hungarian_rmse_metres: 0.4340 - val_loss: 0.5738 - learning_rate: 1.6000e-06
# Epoch 48/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9831 - hungarian_rmse_metres: 0.3511 - loss: 0.2454
# Epoch 48: val_loss improved from 0.57377 to 0.57291, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9816 - hungarian_rmse_metres: 0.3196 - loss: 0.2331 - val_hungarian_mask_acc: 0.9483 - val_hungarian_rmse_metres: 0.4338 - val_loss: 0.5729 - learning_rate: 1.6000e-06
# Epoch 49/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9830 - hungarian_rmse_metres: 0.3516 - loss: 0.2456
# Epoch 49: val_loss improved from 0.57291 to 0.57181, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9817 - hungarian_rmse_metres: 0.3200 - loss: 0.2333 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4337 - val_loss: 0.5718 - learning_rate: 1.6000e-06
# Epoch 50/150
# 4213/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9831 - hungarian_rmse_metres: 0.3504 - loss: 0.2441
# Epoch 50: val_loss improved from 0.57181 to 0.57174, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9818 - hungarian_rmse_metres: 0.3193 - loss: 0.2320 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4338 - val_loss: 0.5717 - learning_rate: 1.6000e-06
# Epoch 51/150
# 4214/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9833 - hungarian_rmse_metres: 0.3513 - loss: 0.2441
# Epoch 51: val_loss improved from 0.57174 to 0.57162, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9819 - hungarian_rmse_metres: 0.3199 - loss: 0.2321 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4337 - val_loss: 0.5716 - learning_rate: 1.6000e-06
# Epoch 52/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9836 - hungarian_rmse_metres: 0.3502 - loss: 0.2428
# Epoch 52: val_loss improved from 0.57162 to 0.57154, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9821 - hungarian_rmse_metres: 0.3190 - loss: 0.2312 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4336 - val_loss: 0.5715 - learning_rate: 1.6000e-06
# Epoch 53/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9836 - hungarian_rmse_metres: 0.3513 - loss: 0.2433
# Epoch 53: val_loss improved from 0.57154 to 0.57012, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9822 - hungarian_rmse_metres: 0.3196 - loss: 0.2311 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4332 - val_loss: 0.5701 - learning_rate: 1.6000e-06
# Epoch 54/150
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9838 - hungarian_rmse_metres: 0.3494 - loss: 0.2403
# Epoch 54: val_loss improved from 0.57012 to 0.56984, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9823 - hungarian_rmse_metres: 0.3187 - loss: 0.2295 - val_hungarian_mask_acc: 0.9486 - val_hungarian_rmse_metres: 0.4332 - val_loss: 0.5698 - learning_rate: 1.6000e-06
# Epoch 55/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9837 - hungarian_rmse_metres: 0.3503 - loss: 0.2423
# Epoch 55: val_loss did not improve from 0.56984
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9821 - hungarian_rmse_metres: 0.3191 - loss: 0.2310 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4333 - val_loss: 0.5702 - learning_rate: 1.6000e-06
# Epoch 56/150
# 4218/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9841 - hungarian_rmse_metres: 0.3497 - loss: 0.2403
# Epoch 56: val_loss did not improve from 0.56984
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9825 - hungarian_rmse_metres: 0.3189 - loss: 0.2291 - val_hungarian_mask_acc: 0.9483 - val_hungarian_rmse_metres: 0.4333 - val_loss: 0.5702 - learning_rate: 1.6000e-06
# Epoch 57/150
# 4218/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9840 - hungarian_rmse_metres: 0.3500 - loss: 0.2398
# Epoch 57: val_loss improved from 0.56984 to 0.56943, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9825 - hungarian_rmse_metres: 0.3189 - loss: 0.2283 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4331 - val_loss: 0.5694 - learning_rate: 1.6000e-06
# Epoch 58/150
# 4218/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9844 - hungarian_rmse_metres: 0.3498 - loss: 0.2393
# Epoch 58: val_loss improved from 0.56943 to 0.56893, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9830 - hungarian_rmse_metres: 0.3189 - loss: 0.2278 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4329 - val_loss: 0.5689 - learning_rate: 1.6000e-06
# Epoch 59/150
# 4212/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9844 - hungarian_rmse_metres: 0.3498 - loss: 0.2395
# Epoch 59: val_loss did not improve from 0.56893
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9830 - hungarian_rmse_metres: 0.3188 - loss: 0.2280 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4331 - val_loss: 0.5691 - learning_rate: 1.6000e-06
# Epoch 60/150
# 4218/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9845 - hungarian_rmse_metres: 0.3499 - loss: 0.2389
# Epoch 60: val_loss did not improve from 0.56893
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9829 - hungarian_rmse_metres: 0.3189 - loss: 0.2276 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4332 - val_loss: 0.5691 - learning_rate: 1.6000e-06
# Epoch 61/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9843 - hungarian_rmse_metres: 0.3498 - loss: 0.2397
# Epoch 61: val_loss did not improve from 0.56893
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9829 - hungarian_rmse_metres: 0.3186 - loss: 0.2276 - val_hungarian_mask_acc: 0.9482 - val_hungarian_rmse_metres: 0.4333 - val_loss: 0.5702 - learning_rate: 1.6000e-06
# Epoch 62/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9846 - hungarian_rmse_metres: 0.3499 - loss: 0.2387
# Epoch 62: val_loss improved from 0.56893 to 0.56850, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9831 - hungarian_rmse_metres: 0.3187 - loss: 0.2272 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4331 - val_loss: 0.5685 - learning_rate: 1.6000e-06
# Epoch 63/150
# 4214/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9845 - hungarian_rmse_metres: 0.3493 - loss: 0.2383
# Epoch 63: val_loss improved from 0.56850 to 0.56809, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - hungarian_mask_acc: 0.9830 - hungarian_rmse_metres: 0.3180 - loss: 0.2267 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4328 - val_loss: 0.5681 - learning_rate: 1.6000e-06
# Epoch 64/150
# 4218/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9844 - hungarian_rmse_metres: 0.3484 - loss: 0.2380
# Epoch 64: val_loss improved from 0.56809 to 0.56798, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9830 - hungarian_rmse_metres: 0.3182 - loss: 0.2271 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4331 - val_loss: 0.5680 - learning_rate: 1.6000e-06
# Epoch 65/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9842 - hungarian_rmse_metres: 0.3490 - loss: 0.2391
# Epoch 65: val_loss did not improve from 0.56798
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9828 - hungarian_rmse_metres: 0.3185 - loss: 0.2273 - val_hungarian_mask_acc: 0.9483 - val_hungarian_rmse_metres: 0.4330 - val_loss: 0.5681 - learning_rate: 1.6000e-06
# Epoch 66/150
# 4218/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9844 - hungarian_rmse_metres: 0.3492 - loss: 0.2378
# Epoch 66: val_loss improved from 0.56798 to 0.56783, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9830 - hungarian_rmse_metres: 0.3184 - loss: 0.2262 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4330 - val_loss: 0.5678 - learning_rate: 1.6000e-06
# Epoch 67/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9846 - hungarian_rmse_metres: 0.3483 - loss: 0.2367
# Epoch 67: val_loss improved from 0.56783 to 0.56720, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9831 - hungarian_rmse_metres: 0.3175 - loss: 0.2259 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4329 - val_loss: 0.5672 - learning_rate: 1.6000e-06
# Epoch 68/150
# 4212/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9841 - hungarian_rmse_metres: 0.3495 - loss: 0.2387
# Epoch 68: val_loss improved from 0.56720 to 0.56693, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9829 - hungarian_rmse_metres: 0.3184 - loss: 0.2264 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4329 - val_loss: 0.5669 - learning_rate: 1.6000e-06
# Epoch 69/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9846 - hungarian_rmse_metres: 0.3487 - loss: 0.2360
# Epoch 69: val_loss improved from 0.56693 to 0.56668, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9831 - hungarian_rmse_metres: 0.3179 - loss: 0.2248 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4328 - val_loss: 0.5667 - learning_rate: 1.6000e-06
# Epoch 70/150
# 4214/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9848 - hungarian_rmse_metres: 0.3487 - loss: 0.2369
# Epoch 70: val_loss did not improve from 0.56668
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9833 - hungarian_rmse_metres: 0.3179 - loss: 0.2253 - val_hungarian_mask_acc: 0.9483 - val_hungarian_rmse_metres: 0.4327 - val_loss: 0.5669 - learning_rate: 1.6000e-06
# Epoch 71/150
# 4213/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9849 - hungarian_rmse_metres: 0.3484 - loss: 0.2358
# Epoch 71: val_loss improved from 0.56668 to 0.56659, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9834 - hungarian_rmse_metres: 0.3180 - loss: 0.2248 - val_hungarian_mask_acc: 0.9483 - val_hungarian_rmse_metres: 0.4327 - val_loss: 0.5666 - learning_rate: 1.6000e-06
# Epoch 72/150
# 4214/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9848 - hungarian_rmse_metres: 0.3488 - loss: 0.2365
# Epoch 72: val_loss did not improve from 0.56659
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9833 - hungarian_rmse_metres: 0.3181 - loss: 0.2253 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4331 - val_loss: 0.5672 - learning_rate: 1.6000e-06
# Epoch 73/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9848 - hungarian_rmse_metres: 0.3481 - loss: 0.2358
# Epoch 73: val_loss improved from 0.56659 to 0.56645, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9833 - hungarian_rmse_metres: 0.3179 - loss: 0.2249 - val_hungarian_mask_acc: 0.9483 - val_hungarian_rmse_metres: 0.4328 - val_loss: 0.5664 - learning_rate: 1.6000e-06
# Epoch 74/150
# 4213/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9851 - hungarian_rmse_metres: 0.3482 - loss: 0.2347
# Epoch 74: val_loss improved from 0.56645 to 0.56571, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9835 - hungarian_rmse_metres: 0.3179 - loss: 0.2242 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4328 - val_loss: 0.5657 - learning_rate: 1.6000e-06
# Epoch 75/150
# 4212/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9850 - hungarian_rmse_metres: 0.3481 - loss: 0.2347
# Epoch 75: val_loss did not improve from 0.56571
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9832 - hungarian_rmse_metres: 0.3176 - loss: 0.2246 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4328 - val_loss: 0.5661 - learning_rate: 1.6000e-06
# Epoch 76/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9851 - hungarian_rmse_metres: 0.3482 - loss: 0.2351
# Epoch 76: val_loss improved from 0.56571 to 0.56554, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9836 - hungarian_rmse_metres: 0.3178 - loss: 0.2240 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4326 - val_loss: 0.5655 - learning_rate: 1.6000e-06
# Epoch 77/150
# 4210/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9852 - hungarian_rmse_metres: 0.3477 - loss: 0.2333
# Epoch 77: val_loss did not improve from 0.56554
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9837 - hungarian_rmse_metres: 0.3176 - loss: 0.2228 - val_hungarian_mask_acc: 0.9483 - val_hungarian_rmse_metres: 0.4326 - val_loss: 0.5658 - learning_rate: 1.6000e-06
# Epoch 78/150
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9854 - hungarian_rmse_metres: 0.3471 - loss: 0.2320
# Epoch 78: val_loss did not improve from 0.56554
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9839 - hungarian_rmse_metres: 0.3168 - loss: 0.2219 - val_hungarian_mask_acc: 0.9482 - val_hungarian_rmse_metres: 0.4326 - val_loss: 0.5658 - learning_rate: 1.6000e-06
# Epoch 79/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9852 - hungarian_rmse_metres: 0.3480 - loss: 0.2346
# Epoch 79: val_loss improved from 0.56554 to 0.56504, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - hungarian_mask_acc: 0.9837 - hungarian_rmse_metres: 0.3176 - loss: 0.2235 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4325 - val_loss: 0.5650 - learning_rate: 1.6000e-06
# Epoch 80/150
# 4218/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9852 - hungarian_rmse_metres: 0.3477 - loss: 0.2343
# Epoch 80: val_loss improved from 0.56504 to 0.56486, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - hungarian_mask_acc: 0.9838 - hungarian_rmse_metres: 0.3174 - loss: 0.2230 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4329 - val_loss: 0.5649 - learning_rate: 1.6000e-06
# Epoch 81/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9851 - hungarian_rmse_metres: 0.3475 - loss: 0.2341
# Epoch 81: val_loss did not improve from 0.56486
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9837 - hungarian_rmse_metres: 0.3173 - loss: 0.2231 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4327 - val_loss: 0.5650 - learning_rate: 1.6000e-06
# Epoch 82/150
# 4213/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9853 - hungarian_rmse_metres: 0.3472 - loss: 0.2332
# Epoch 82: val_loss improved from 0.56486 to 0.56452, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9838 - hungarian_rmse_metres: 0.3172 - loss: 0.2224 - val_hungarian_mask_acc: 0.9486 - val_hungarian_rmse_metres: 0.4330 - val_loss: 0.5645 - learning_rate: 1.6000e-06
# Epoch 83/150
# 4212/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9854 - hungarian_rmse_metres: 0.3468 - loss: 0.2321
# Epoch 83: val_loss did not improve from 0.56452
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9838 - hungarian_rmse_metres: 0.3171 - loss: 0.2225 - val_hungarian_mask_acc: 0.9486 - val_hungarian_rmse_metres: 0.4329 - val_loss: 0.5648 - learning_rate: 1.6000e-06
# Epoch 84/150
# 4212/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9858 - hungarian_rmse_metres: 0.3471 - loss: 0.2323
# Epoch 84: val_loss did not improve from 0.56452
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9841 - hungarian_rmse_metres: 0.3168 - loss: 0.2216 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4325 - val_loss: 0.5650 - learning_rate: 1.6000e-06
# Epoch 85/150
# 4218/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9854 - hungarian_rmse_metres: 0.3480 - loss: 0.2328
# Epoch 85: val_loss did not improve from 0.56452
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9838 - hungarian_rmse_metres: 0.3173 - loss: 0.2220 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4327 - val_loss: 0.5656 - learning_rate: 1.6000e-06
# Epoch 86/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9854 - hungarian_rmse_metres: 0.3477 - loss: 0.2328
# Epoch 86: val_loss improved from 0.56452 to 0.56430, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9840 - hungarian_rmse_metres: 0.3176 - loss: 0.2220 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4325 - val_loss: 0.5643 - learning_rate: 1.6000e-06
# Epoch 87/150
# 4213/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9857 - hungarian_rmse_metres: 0.3469 - loss: 0.2314
# Epoch 87: val_loss improved from 0.56430 to 0.56410, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9844 - hungarian_rmse_metres: 0.3168 - loss: 0.2208 - val_hungarian_mask_acc: 0.9486 - val_hungarian_rmse_metres: 0.4324 - val_loss: 0.5641 - learning_rate: 1.6000e-06
# Epoch 88/150
# 4210/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9855 - hungarian_rmse_metres: 0.3467 - loss: 0.2312
# Epoch 88: val_loss did not improve from 0.56410
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9840 - hungarian_rmse_metres: 0.3166 - loss: 0.2205 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4325 - val_loss: 0.5641 - learning_rate: 1.6000e-06
# Epoch 89/150
# 4213/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9858 - hungarian_rmse_metres: 0.3471 - loss: 0.2315
# Epoch 89: val_loss improved from 0.56410 to 0.56371, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9841 - hungarian_rmse_metres: 0.3169 - loss: 0.2211 - val_hungarian_mask_acc: 0.9486 - val_hungarian_rmse_metres: 0.4327 - val_loss: 0.5637 - learning_rate: 1.6000e-06
# Epoch 90/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9854 - hungarian_rmse_metres: 0.3475 - loss: 0.2318
# Epoch 90: val_loss improved from 0.56371 to 0.56268, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9840 - hungarian_rmse_metres: 0.3170 - loss: 0.2209 - val_hungarian_mask_acc: 0.9486 - val_hungarian_rmse_metres: 0.4320 - val_loss: 0.5627 - learning_rate: 1.6000e-06
# Epoch 91/150
# 4216/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9857 - hungarian_rmse_metres: 0.3469 - loss: 0.2311
# Epoch 91: val_loss improved from 0.56268 to 0.56215, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9840 - hungarian_rmse_metres: 0.3168 - loss: 0.2211 - val_hungarian_mask_acc: 0.9487 - val_hungarian_rmse_metres: 0.4324 - val_loss: 0.5621 - learning_rate: 1.6000e-06
# Epoch 92/150
# 4212/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9855 - hungarian_rmse_metres: 0.3472 - loss: 0.2314
# Epoch 92: val_loss did not improve from 0.56215
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9842 - hungarian_rmse_metres: 0.3170 - loss: 0.2207 - val_hungarian_mask_acc: 0.9484 - val_hungarian_rmse_metres: 0.4325 - val_loss: 0.5640 - learning_rate: 1.6000e-06
# Epoch 93/150
# 4214/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9856 - hungarian_rmse_metres: 0.3469 - loss: 0.2307
# Epoch 93: val_loss did not improve from 0.56215
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9841 - hungarian_rmse_metres: 0.3168 - loss: 0.2204 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4324 - val_loss: 0.5634 - learning_rate: 1.6000e-06
# Epoch 94/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9856 - hungarian_rmse_metres: 0.3468 - loss: 0.2316
# Epoch 94: val_loss did not improve from 0.56215
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9841 - hungarian_rmse_metres: 0.3166 - loss: 0.2207 - val_hungarian_mask_acc: 0.9487 - val_hungarian_rmse_metres: 0.4322 - val_loss: 0.5623 - learning_rate: 1.6000e-06
# Epoch 95/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9859 - hungarian_rmse_metres: 0.3468 - loss: 0.2300
# Epoch 95: val_loss did not improve from 0.56215
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9842 - hungarian_rmse_metres: 0.3165 - loss: 0.2196 - val_hungarian_mask_acc: 0.9485 - val_hungarian_rmse_metres: 0.4322 - val_loss: 0.5631 - learning_rate: 1.6000e-06
# Epoch 96/150
# 4216/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9858 - hungarian_rmse_metres: 0.3469 - loss: 0.2310
# Epoch 96: val_loss did not improve from 0.56215
#
# Epoch 96: ReduceLROnPlateau reducing learning rate to 1e-06.
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9843 - hungarian_rmse_metres: 0.3168 - loss: 0.2201 - val_hungarian_mask_acc: 0.9486 - val_hungarian_rmse_metres: 0.4324 - val_loss: 0.5626 - learning_rate: 1.6000e-06
# Epoch 97/150
# 4213/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9853 - hungarian_rmse_metres: 0.3477 - loss: 0.2329
# Epoch 97: val_loss improved from 0.56215 to 0.55985, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9841 - hungarian_rmse_metres: 0.3169 - loss: 0.2205 - val_hungarian_mask_acc: 0.9489 - val_hungarian_rmse_metres: 0.4314 - val_loss: 0.5598 - learning_rate: 1.0000e-06
# Epoch 98/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9856 - hungarian_rmse_metres: 0.3477 - loss: 0.2321
# Epoch 98: val_loss improved from 0.55985 to 0.55929, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9841 - hungarian_rmse_metres: 0.3174 - loss: 0.2215 - val_hungarian_mask_acc: 0.9490 - val_hungarian_rmse_metres: 0.4309 - val_loss: 0.5593 - learning_rate: 1.0000e-06
# Epoch 99/150
# 4212/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9859 - hungarian_rmse_metres: 0.3478 - loss: 0.2316
# Epoch 99: val_loss did not improve from 0.55929
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9843 - hungarian_rmse_metres: 0.3172 - loss: 0.2206 - val_hungarian_mask_acc: 0.9489 - val_hungarian_rmse_metres: 0.4310 - val_loss: 0.5603 - learning_rate: 1.0000e-06
# Epoch 100/150
# 4218/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9859 - hungarian_rmse_metres: 0.3466 - loss: 0.2301
# Epoch 100: val_loss did not improve from 0.55929
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9842 - hungarian_rmse_metres: 0.3167 - loss: 0.2202 - val_hungarian_mask_acc: 0.9489 - val_hungarian_rmse_metres: 0.4311 - val_loss: 0.5603 - learning_rate: 1.0000e-06
# Epoch 101/150
# 4213/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9861 - hungarian_rmse_metres: 0.3463 - loss: 0.2294
# Epoch 101: val_loss did not improve from 0.55929
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9843 - hungarian_rmse_metres: 0.3168 - loss: 0.2202 - val_hungarian_mask_acc: 0.9491 - val_hungarian_rmse_metres: 0.4309 - val_loss: 0.5595 - learning_rate: 1.0000e-06
# Epoch 102/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9862 - hungarian_rmse_metres: 0.3469 - loss: 0.2294
# Epoch 102: val_loss did not improve from 0.55929
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9844 - hungarian_rmse_metres: 0.3168 - loss: 0.2201 - val_hungarian_mask_acc: 0.9490 - val_hungarian_rmse_metres: 0.4310 - val_loss: 0.5601 - learning_rate: 1.0000e-06
# Epoch 103/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9859 - hungarian_rmse_metres: 0.3465 - loss: 0.2299
# Epoch 103: val_loss did not improve from 0.55929
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9843 - hungarian_rmse_metres: 0.3165 - loss: 0.2201 - val_hungarian_mask_acc: 0.9490 - val_hungarian_rmse_metres: 0.4311 - val_loss: 0.5602 - learning_rate: 1.0000e-06
# Epoch 104/150
# 4214/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9858 - hungarian_rmse_metres: 0.3472 - loss: 0.2301
# Epoch 104: val_loss did not improve from 0.55929
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9839 - hungarian_rmse_metres: 0.3168 - loss: 0.2203 - val_hungarian_mask_acc: 0.9491 - val_hungarian_rmse_metres: 0.4310 - val_loss: 0.5596 - learning_rate: 1.0000e-06
# Epoch 105/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9861 - hungarian_rmse_metres: 0.3465 - loss: 0.2296
# Epoch 105: val_loss did not improve from 0.55929
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9842 - hungarian_rmse_metres: 0.3167 - loss: 0.2203 - val_hungarian_mask_acc: 0.9492 - val_hungarian_rmse_metres: 0.4311 - val_loss: 0.5594 - learning_rate: 1.0000e-06
# Epoch 106/150
# 4213/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9859 - hungarian_rmse_metres: 0.3467 - loss: 0.2300
# Epoch 106: val_loss did not improve from 0.55929
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9844 - hungarian_rmse_metres: 0.3168 - loss: 0.2198 - val_hungarian_mask_acc: 0.9491 - val_hungarian_rmse_metres: 0.4309 - val_loss: 0.5595 - learning_rate: 1.0000e-06
# Epoch 107/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9861 - hungarian_rmse_metres: 0.3472 - loss: 0.2301
# Epoch 107: val_loss improved from 0.55929 to 0.55823, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9845 - hungarian_rmse_metres: 0.3169 - loss: 0.2195 - val_hungarian_mask_acc: 0.9492 - val_hungarian_rmse_metres: 0.4305 - val_loss: 0.5582 - learning_rate: 1.0000e-06
# Epoch 108/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9865 - hungarian_rmse_metres: 0.3472 - loss: 0.2293
# Epoch 108: val_loss did not improve from 0.55823
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9848 - hungarian_rmse_metres: 0.3171 - loss: 0.2196 - val_hungarian_mask_acc: 0.9491 - val_hungarian_rmse_metres: 0.4310 - val_loss: 0.5591 - learning_rate: 1.0000e-06
# Epoch 109/150
# 4212/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9861 - hungarian_rmse_metres: 0.3464 - loss: 0.2287
# Epoch 109: val_loss did not improve from 0.55823
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9843 - hungarian_rmse_metres: 0.3165 - loss: 0.2193 - val_hungarian_mask_acc: 0.9491 - val_hungarian_rmse_metres: 0.4311 - val_loss: 0.5596 - learning_rate: 1.0000e-06
# Epoch 110/150
# 4213/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9861 - hungarian_rmse_metres: 0.3464 - loss: 0.2293
# Epoch 110: val_loss did not improve from 0.55823
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9844 - hungarian_rmse_metres: 0.3164 - loss: 0.2192 - val_hungarian_mask_acc: 0.9492 - val_hungarian_rmse_metres: 0.4311 - val_loss: 0.5587 - learning_rate: 1.0000e-06
# Epoch 111/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9859 - hungarian_rmse_metres: 0.3466 - loss: 0.2302
# Epoch 111: val_loss improved from 0.55823 to 0.55812, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - hungarian_mask_acc: 0.9843 - hungarian_rmse_metres: 0.3167 - loss: 0.2197 - val_hungarian_mask_acc: 0.9492 - val_hungarian_rmse_metres: 0.4307 - val_loss: 0.5581 - learning_rate: 1.0000e-06
# Epoch 112/150
# 4214/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9863 - hungarian_rmse_metres: 0.3472 - loss: 0.2291
# Epoch 112: val_loss did not improve from 0.55812
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9846 - hungarian_rmse_metres: 0.3169 - loss: 0.2192 - val_hungarian_mask_acc: 0.9492 - val_hungarian_rmse_metres: 0.4309 - val_loss: 0.5586 - learning_rate: 1.0000e-06
# Epoch 113/150
# 4213/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9864 - hungarian_rmse_metres: 0.3469 - loss: 0.2288
# Epoch 113: val_loss did not improve from 0.55812
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9846 - hungarian_rmse_metres: 0.3169 - loss: 0.2192 - val_hungarian_mask_acc: 0.9490 - val_hungarian_rmse_metres: 0.4311 - val_loss: 0.5591 - learning_rate: 1.0000e-06
# Epoch 114/150
# 4212/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9859 - hungarian_rmse_metres: 0.3466 - loss: 0.2295
# Epoch 114: val_loss did not improve from 0.55812
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9843 - hungarian_rmse_metres: 0.3164 - loss: 0.2192 - val_hungarian_mask_acc: 0.9490 - val_hungarian_rmse_metres: 0.4311 - val_loss: 0.5594 - learning_rate: 1.0000e-06
# Epoch 115/150
# 4216/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9860 - hungarian_rmse_metres: 0.3459 - loss: 0.2293
# Epoch 115: val_loss did not improve from 0.55812
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9844 - hungarian_rmse_metres: 0.3163 - loss: 0.2192 - val_hungarian_mask_acc: 0.9492 - val_hungarian_rmse_metres: 0.4309 - val_loss: 0.5582 - learning_rate: 1.0000e-06
# Epoch 116/150
# 4214/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9866 - hungarian_rmse_metres: 0.3465 - loss: 0.2284
# Epoch 116: val_loss improved from 0.55812 to 0.55810, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9848 - hungarian_rmse_metres: 0.3166 - loss: 0.2189 - val_hungarian_mask_acc: 0.9490 - val_hungarian_rmse_metres: 0.4309 - val_loss: 0.5581 - learning_rate: 1.0000e-06
# Epoch 117/150
# 4214/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9862 - hungarian_rmse_metres: 0.3472 - loss: 0.2288
# Epoch 117: val_loss did not improve from 0.55810
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9845 - hungarian_rmse_metres: 0.3170 - loss: 0.2191 - val_hungarian_mask_acc: 0.9490 - val_hungarian_rmse_metres: 0.4309 - val_loss: 0.5582 - learning_rate: 1.0000e-06
# Epoch 118/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9864 - hungarian_rmse_metres: 0.3459 - loss: 0.2274
# Epoch 118: val_loss did not improve from 0.55810
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9845 - hungarian_rmse_metres: 0.3161 - loss: 0.2183 - val_hungarian_mask_acc: 0.9491 - val_hungarian_rmse_metres: 0.4310 - val_loss: 0.5582 - learning_rate: 1.0000e-06
# Epoch 119/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9863 - hungarian_rmse_metres: 0.3470 - loss: 0.2295
# Epoch 119: val_loss did not improve from 0.55810
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9845 - hungarian_rmse_metres: 0.3166 - loss: 0.2192 - val_hungarian_mask_acc: 0.9490 - val_hungarian_rmse_metres: 0.4309 - val_loss: 0.5591 - learning_rate: 1.0000e-06
# Epoch 120/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9862 - hungarian_rmse_metres: 0.3468 - loss: 0.2290
# Epoch 120: val_loss did not improve from 0.55810
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9845 - hungarian_rmse_metres: 0.3167 - loss: 0.2188 - val_hungarian_mask_acc: 0.9488 - val_hungarian_rmse_metres: 0.4307 - val_loss: 0.5592 - learning_rate: 1.0000e-06
# Epoch 121/150
# 4213/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9863 - hungarian_rmse_metres: 0.3464 - loss: 0.2283
# Epoch 121: val_loss did not improve from 0.55810
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9845 - hungarian_rmse_metres: 0.3164 - loss: 0.2185 - val_hungarian_mask_acc: 0.9490 - val_hungarian_rmse_metres: 0.4309 - val_loss: 0.5584 - learning_rate: 1.0000e-06
# Epoch 122/150
# 4213/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9864 - hungarian_rmse_metres: 0.3461 - loss: 0.2279
# Epoch 122: val_loss improved from 0.55810 to 0.55777, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9850 - hungarian_rmse_metres: 0.3160 - loss: 0.2175 - val_hungarian_mask_acc: 0.9491 - val_hungarian_rmse_metres: 0.4306 - val_loss: 0.5578 - learning_rate: 1.0000e-06
# Epoch 123/150
# 4218/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9864 - hungarian_rmse_metres: 0.3466 - loss: 0.2278
# Epoch 123: val_loss did not improve from 0.55777
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9847 - hungarian_rmse_metres: 0.3164 - loss: 0.2178 - val_hungarian_mask_acc: 0.9491 - val_hungarian_rmse_metres: 0.4306 - val_loss: 0.5578 - learning_rate: 1.0000e-06
# Epoch 124/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9861 - hungarian_rmse_metres: 0.3464 - loss: 0.2284
# Epoch 124: val_loss did not improve from 0.55777
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9844 - hungarian_rmse_metres: 0.3164 - loss: 0.2183 - val_hungarian_mask_acc: 0.9489 - val_hungarian_rmse_metres: 0.4305 - val_loss: 0.5589 - learning_rate: 1.0000e-06
# Epoch 125/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9867 - hungarian_rmse_metres: 0.3458 - loss: 0.2269
# Epoch 125: val_loss improved from 0.55777 to 0.55717, saving model to split9.keras
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9849 - hungarian_rmse_metres: 0.3161 - loss: 0.2175 - val_hungarian_mask_acc: 0.9491 - val_hungarian_rmse_metres: 0.4304 - val_loss: 0.5572 - learning_rate: 1.0000e-06
# Epoch 126/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9864 - hungarian_rmse_metres: 0.3459 - loss: 0.2278
# Epoch 126: val_loss did not improve from 0.55717
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9847 - hungarian_rmse_metres: 0.3163 - loss: 0.2181 - val_hungarian_mask_acc: 0.9489 - val_hungarian_rmse_metres: 0.4307 - val_loss: 0.5584 - learning_rate: 1.0000e-06
# Epoch 127/150
# 4215/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9864 - hungarian_rmse_metres: 0.3468 - loss: 0.2287
# Epoch 127: val_loss did not improve from 0.55717
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9845 - hungarian_rmse_metres: 0.3168 - loss: 0.2192 - val_hungarian_mask_acc: 0.9490 - val_hungarian_rmse_metres: 0.4307 - val_loss: 0.5584 - learning_rate: 1.0000e-06
# Epoch 128/150
# 4211/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9863 - hungarian_rmse_metres: 0.3461 - loss: 0.2276
# Epoch 128: val_loss did not improve from 0.55717
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9847 - hungarian_rmse_metres: 0.3164 - loss: 0.2179 - val_hungarian_mask_acc: 0.9490 - val_hungarian_rmse_metres: 0.4304 - val_loss: 0.5580 - learning_rate: 1.0000e-06
# Epoch 129/150
# 4217/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9864 - hungarian_rmse_metres: 0.3465 - loss: 0.2278
# Epoch 129: val_loss did not improve from 0.55717
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9848 - hungarian_rmse_metres: 0.3166 - loss: 0.2175 - val_hungarian_mask_acc: 0.9489 - val_hungarian_rmse_metres: 0.4310 - val_loss: 0.5586 - learning_rate: 1.0000e-06
# Epoch 130/150
# 4212/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9865 - hungarian_rmse_metres: 0.3465 - loss: 0.2280
# Epoch 130: val_loss did not improve from 0.55717
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9848 - hungarian_rmse_metres: 0.3164 - loss: 0.2179 - val_hungarian_mask_acc: 0.9489 - val_hungarian_rmse_metres: 0.4310 - val_loss: 0.5589 - learning_rate: 1.0000e-06
# Epoch 131/150
# 4213/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9865 - hungarian_rmse_metres: 0.3459 - loss: 0.2278
# Epoch 131: val_loss did not improve from 0.55717
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9848 - hungarian_rmse_metres: 0.3162 - loss: 0.2181 - val_hungarian_mask_acc: 0.9492 - val_hungarian_rmse_metres: 0.4307 - val_loss: 0.5578 - learning_rate: 1.0000e-06
# Epoch 132/150
# 4218/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9864 - hungarian_rmse_metres: 0.3463 - loss: 0.2279
# Epoch 132: val_loss did not improve from 0.55717
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9851 - hungarian_rmse_metres: 0.3160 - loss: 0.2170 - val_hungarian_mask_acc: 0.9490 - val_hungarian_rmse_metres: 0.4308 - val_loss: 0.5584 - learning_rate: 1.0000e-06
# Epoch 133/150
# 4218/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9865 - hungarian_rmse_metres: 0.3466 - loss: 0.2283
# Epoch 133: val_loss did not improve from 0.55717
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9849 - hungarian_rmse_metres: 0.3164 - loss: 0.2173 - val_hungarian_mask_acc: 0.9488 - val_hungarian_rmse_metres: 0.4311 - val_loss: 0.5589 - learning_rate: 1.0000e-06
# Epoch 134/150
# 4212/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9865 - hungarian_rmse_metres: 0.3459 - loss: 0.2273
# Epoch 134: val_loss did not improve from 0.55717
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - hungarian_mask_acc: 0.9846 - hungarian_rmse_metres: 0.3162 - loss: 0.2176 - val_hungarian_mask_acc: 0.9489 - val_hungarian_rmse_metres: 0.4307 - val_loss: 0.5582 - learning_rate: 1.0000e-06
# Epoch 135/150
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - hungarian_mask_acc: 0.9866 - hungarian_rmse_metres: 0.3462 - loss: 0.2267
# Epoch 135: val_loss did not improve from 0.55717
# 4219/4219 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - hungarian_mask_acc: 0.9850 - hungarian_rmse_metres: 0.3163 - loss: 0.2169 - val_hungarian_mask_acc: 0.9490 - val_hungarian_rmse_metres: 0.4306 - val_loss: 0.5575 - learning_rate: 1.0000e-06
# Epoch 135: early stopping
# Restoring model weights from the end of the best epoch: 125.
# --- ADDESTRAMENTO COMPLETATO ---

# %% [markdown]
# split 1 0.52373
# split 2 0.40538
# split 3 1.06804
# split 4 0.79029 1 epoch
# split 5 0.51156
# split 6 0.40289
# split 7 0.54835
# split 8 0.55794
# split 9
